# %%
import os
import numpy as np
import pandas as pd

# %%
def dir_files(dir_path):
    return [os.path.join(dir_path,f) for f in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, f))]

# %%
data_dir = r'C:\Users\asaf\Desktop\DS_workshop-project\stock_market_neural_nets\data\relevant\dukascopy\BID'
save_skipped = r'C:\Users\asaf\Desktop\DS_workshop-project\stock_market_neural_nets\data\relevant\dukascopy\feather\skipped.csv'
csv_files = dir_files(data_dir)

# %%
skipped = []
count = 1
for file in csv_files:
    print(count, os.path.basename(file))
    count+=1
    
    df = pd.read_csv(file)
    
    # rename columns
    new_cols_map = {col: col.lower() for col in df}
    new_cols_map['Local time'] = "datetime"
    df.rename(columns=new_cols_map, inplace=True)

    # convert to datetime
    df['datetime'] = df['datetime'].str.replace(r"\:00\.000 GMT\+0\d00","")
    df['datetime'] = pd.to_datetime(df['datetime'], format='%d.%m.%Y %H:%M')
    
    # drop duplicates (daylight saving time)
    df = df[~df.duplicated()]
    
    # drop saturdays and sundays
    mask = (df['datetime'].dt.dayofweek==5) | (df['datetime'].dt.dayofweek==6)
    if (mask & (df['volume']!=0)).any():
        skipped.append((file, "weekends with none 0 volume"))
        continue
    df = df[~mask]
    
    # drop inactive hours
    mask = ((df['datetime'].dt.hour*100 + df['datetime'].dt.minute < 1530) | \
           ( df['datetime'].dt.hour*100 + df['datetime'].dt.minute > 2300))
    if (mask & df['volume']!=0).any():
        skipped.append((file, "non trading hours with volume different than 0"))
        continue
    mask = ~mask & (df['volume']!=0)
    df = df[mask]
    
    # sort by datetime
    df.sort_values(by=['datetime'], inplace=True)
    
    # reset index, more convenient
    df.reset_index(drop=True, inplace=True)
    
    # save data in feather format
    file_name = os.path.basename(file).replace(".csv", ".feather")
    df.to_feather(os.path.join(save_dir, file_name))
# Out:
# 1 A.USUSD.csv
# 2 AA.USUSD.csv
# 3 AABA.USUSD.csv
# 4 AAL.GBGBX.csv
# 5 AAL.USUSD.csv
# 6 AAPL.USUSD.csv
# 7 ABBN.CHCHF.csv
# 8 ABC.USUSD.csv
# 9 ABEV.USUSD.csv
# 10 ABF.GBGBX.csv
# 11 ABI.BEEUR.csv
# 12 ABT.USUSD.csv
# 13 AC.FREUR.csv
# 14 ACA.FREUR.csv
# 15 ACS.ESEUR.csv
# 16 ACX.ESEUR.csv
# 17 ADBE.USUSD.csv
# 18 ADEN.CHCHF.csv
# 19 ADI.USUSD.csv
# 20 ADM.GBGBX.csv
# 21 ADP.USUSD.csv
# 22 ADS.DEEUR.csv
# 23 ADSK.USUSD.csv
# 24 AENA.ESEUR.csv
# 25 AET.USUSD.csv
# 26 AF.FREUR.csv
# 27 AGK.GBGBX.csv
# 28 AGN.NLEUR.csv
# 29 AGS.BEEUR.csv
# 30 AH.NLEUR.csv
# 31 AHT.GBGBX.csv
# 32 AI.FREUR.csv
# 33 AIG.USUSD.csv
# 34 AIR.FREUR.csv
# 35 AKZA.NLEUR.csv
# 36 ALFA.SESEK.csv
# 37 ALL.USUSD.csv
# 38 ALO.FREUR.csv
# 39 ALV.DEEUR.csv
# 40 ALXN.USUSD.csv
# 41 AMAT.USUSD.csv
# 42 AMD.USUSD.csv
# 43 AMGN.USUSD.csv
# 44 AMS.ESEUR.csv
# 45 AMT.USUSD.csv
# 46 AMZN.USUSD.csv
# 47 ANTM.USUSD.csv
# 48 ANTO.GBGBX.csv
# 49 APA.USUSD.csv
# 50 APC.USUSD.csv
# 51 APD.USUSD.csv
# 52 ASML.NLEUR.csv
# 53 ATCOA.SESEK.csv
# 54 ATVI.USUSD.csv
# 55 AUDCAD.csv
# 56 AUDCHF.csv
# 57 AUDJPY.csv
# 58 AUDNZD.csv
# 59 AUDSGD.csv
# 60 AUDUSD.csv
# 61 AUS.IDXAUD.csv
# 62 AV.GBGBX.csv
# 63 AVB.USUSD.csv
# 64 AVGO.USUSD.csv
# 65 AXP.USUSD.csv
# 66 AZN.GBGBX.csv
# 67 AZN.USUSD.csv
# 68 AZO.USUSD.csv
# 69 BA.GBGBX.csv
# 70 BA.USUSD.csv
# 71 BAB.GBGBX.csv
# 72 BABA.USUSD.csv
# 73 BAC.USUSD.csv
# 74 BAER.CHCHF.csv
# 75 BARC.GBGBX.csv
# 76 BAS.DEEUR.csv
# 77 BATS.GBGBX.csv
# 78 BAYN.DEEUR.csv
# 79 BBD.USUSD.csv
# 80 BBT.USUSD.csv
# 81 BBVA.ESEUR.csv
# 82 BBY.USUSD.csv
# 83 BDX.USUSD.csv
# 84 BEI.DEEUR.csv
# 85 BELG.BEEUR.csv
# 86 BIDU.USUSD.csv
# 87 BIIB.USUSD.csv
# 88 BK.USUSD.csv
# 89 BLND.GBGBX.csv
# 90 BLT.GBGBX.csv
# 91 BMW.DEEUR.csv
# 92 BMY.USUSD.csv
# 93 BN.FREUR.csv
# 94 BNP.FREUR.csv
# 95 BNZL.GBGBX.csv
# 96 BOSS.DEEUR.csv
# 97 BP.GBGBX.csv
# 98 BP.USUSD.csv
# 99 BRBY.GBGBX.csv
# 100 BRENT.CMDUSD.csv
# 101 BRKB.USUSD.csv
# 102 BSX.USUSD.csv
# 103 BT.GBGBX.csv
# 104 BTCUSD.csv
# 105 BUND.TREUR.csv
# 106 C.USUSD.csv
# 107 CA.FREUR.csv
# 108 CABK.ESEUR.csv
# 109 CADCHF.csv
# 110 CADHKD.csv
# 111 CADJPY.csv
# 112 CAG.USUSD.csv
# 113 CAH.USUSD.csv
# 114 CAP.FREUR.csv
# 115 CARLB.DKDKK.csv
# 116 CAT.USUSD.csv
# 117 CBK.DEEUR.csv
# 118 CBS.USUSD.csv
# 119 CCL.GBGBX.csv
# 120 CELG.USUSD.csv
# 121 CF.USUSD.csv
# 122 CHE.IDXCHF.csv
# 123 CHFJPY.csv
# 124 CHFSGD.csv
# 125 CHI.IDXUSD.csv
# 126 CI.USUSD.csv
# 127 CL.USUSD.csv
# 128 CLN.CHCHF.csv
# 129 CMCSA.USUSD.csv
# 130 CME.USUSD.csv
# 131 CMG.USUSD.csv
# 132 CMI.USUSD.csv
# 133 CNA.GBGBX.csv
# 134 COCOA.CMDUSD.csv
# 135 COFFEE.CMDUSX.csv
# 136 COL.USUSD.csv
# 137 COLOB.DKDKK.csv
# 138 COP.USUSD.csv
# 139 COPPER.CMDUSD.csv
# 140 COST.USUSD.csv
# 141 COTTON.CMDUSX.csv
# 142 CPG.GBGBX.csv
# 143 CPI.GBGBX.csv
# 144 CRDA.GBGBX.csv
# 145 CRH.GBGBX.csv
# 146 CRM.USUSD.csv
# 147 CS.FREUR.csv
# 148 CS.USUSD.csv
# 149 CSCO.USUSD.csv
# 150 CSGN.CHCHF.csv
# 151 CSX.USUSD.csv
# 152 CTL.USUSD.csv
# 153 CTSH.USUSD.csv
# 154 CVS.USUSD.csv
# 155 CVX.USUSD.csv
# 156 D.USUSD.csv
# 157 DAI.DEEUR.csv
# 158 DAL.USUSD.csv
# 159 DANSKE.DKDKK.csv
# 160 DB1.DEEUR.csv
# 161 DBK.DEEUR.csv
# 162 DE.USUSD.csv
# 163 DEU.IDXEUR.csv
# 164 DFS.USUSD.csv
# 165 DG.FREUR.csv
# 166 DG.USUSD.csv
# 167 DGE.GBGBX.csv
# 168 DHI.USUSD.csv
# 169 DHR.USUSD.csv
# 170 DIA.ESEUR.csv
# 171 DIA.USUSD.csv
# 172 DIESEL.CMDUSD.csv
# 173 DIS.USUSD.csv
# 174 DLTR.USUSD.csv
# 175 DNB.NONOK.csv
# 176 DOLLAR.IDXUSD.csv
# 177 DPW.DEEUR.csv
# 178 DSM.NLEUR.csv
# 179 DTE.DEEUR.csv
# 180 DUK.USUSD.csv
# 181 DVA.USUSD.csv
# 182 DVN.USUSD.csv
# 183 DVY.USUSD.csv
# 184 EA.USUSD.csv
# 185 EBAY.USUSD.csv
# 186 EBS.ATEUR.csv
# 187 EDF.FREUR.csv
# 188 EDP.PTEUR.csv
# 189 EEM.USUSD.csv
# 190 EFA.USUSD.csv
# 191 EFX.USUSD.csv
# 192 EIX.USUSD.csv
# 193 EL.USUSD.csv
# 194 ELE.ESEUR.csv
# 195 ELI1V.FIEUR.csv
# 196 ELUXB.SESEK.csv
# 197 EMB.USUSD.csv
# 198 EMR.USUSD.csv
# 199 EN.FREUR.csv
# 200 ENG.ESEUR.csv
# 201 ENGI.FREUR.csv
# 202 EOAN.DEEUR.csv
# 203 EOG.USUSD.csv
# 204 EQT.USUSD.csv
# 205 ERICB.SESEK.csv
# 206 ESP.IDXEUR.csv
# 207 ESRX.USUSD.csv
# 208 ETHUSD.csv
# 209 EURAUD.csv
# 210 EURCAD.csv
# 211 EURCHF.csv
# 212 EURCZK.csv
# 213 EURDKK.csv
# 214 EURGBP.csv
# 215 EURHKD.csv
# 216 EURHUF.csv
# 217 EURJPY.csv
# 218 EURNOK.csv
# 219 EURNZD.csv
# 220 EURPLN.csv
# 221 EURRUB.csv
# 222 EURSEK.csv
# 223 EURSGD.csv
# 224 EURTRY.csv
# 225 EURUSD.csv
# 226 EUS.IDXEUR.csv
# 227 EWH.USUSD.csv
# 228 EWJ.USUSD.csv
# 229 EWW.USUSD.csv
# 230 EWZ.USUSD.csv
# 231 EXC.USUSD.csv
# 232 EXPE.USUSD.csv
# 233 EXPN.GBGBX.csv
# 234 EZJ.GBGBX.csv
# 235 EZU.USUSD.csv
# 236 F.USUSD.csv
# 237 FB.USUSD.csv
# 238 FCX.USUSD.csv
# 239 FDX.USUSD.csv
# 240 FE.USUSD.csv
# 241 FER.ESEUR.csv
# 242 FME.DEEUR.csv
# 243 FOXA.USUSD.csv
# 244 FP.FREUR.csv
# 245 FR.FREUR.csv
# 246 FRA.IDXEUR.csv
# 247 FRE.DEEUR.csv
# 248 FRES.GBGBX.csv
# 249 FXI.USUSD.csv
# 250 GALP.PTEUR.csv
# 251 GAM.ESEUR.csv
# 252 GAS.CMDUSD.csv
# 253 GAS.ESEUR.csv
# 254 GBPAUD.csv
# 255 GBPCAD.csv
# 256 GBPCHF.csv
# 257 GBPJPY.csv
# 258 GBPNZD.csv
# 259 GBPUSD.csv
# 260 GBR.IDXGBP.csv
# 261 GDX.USUSD.csv
# 262 GDXJ.USUSD.csv
# 263 GE.USUSD.csv
# 264 GETIB.SESEK.csv
# 265 GFS.GBGBX.csv
# 266 GILD.USUSD.csv
# 267 GIS.USUSD.csv
# 268 GIVN.CHCHF.csv
# 269 GLD.USUSD.csv
# 270 GLE.FREUR.csv
# 271 GLEN.GBGBX.csv
# 272 GLW.USUSD.csv
# 273 GM.USUSD.csv
# 274 GOOG.USUSD.csv
# 275 GOOGL.USUSD.csv
# 276 GPS.USUSD.csv
# 277 GS.USUSD.csv
# 278 GWW.USUSD.csv
# 279 HAL.USUSD.csv
# 280 HCN.USUSD.csv
# 281 HCP.USUSD.csv
# 282 HD.USUSD.csv
# 283 HEI.DEEUR.csv
# 284 HEIA.NLEUR.csv
# 285 HEN3.DEEUR.csv
# 286 HES.USUSD.csv
# 287 HKDJPY.csv
# 288 HKG.IDXHKD.csv
# 289 HMB.SESEK.csv
# 290 HMSO.GBGBX.csv
# 291 HON.USUSD.csv
# 292 HPQ.USUSD.csv
# 293 HSBA.GBGBX.csv
# 294 HUM.USUSD.csv
# 295 IAG.GBGBX.csv
# 296 IBB.USUSD.csv
# 297 IBE.ESEUR.csv
# 298 IBM.USUSD.csv
# 299 ICE.USUSD.csv
# 300 IEF.USUSD.csv
# 301 IFX.DEEUR.csv
# 302 IHG.GBGBX.csv
# 303 IJH.USUSD.csv
# 304 IJR.USUSD.csv
# 305 ILMN.USUSD.csv
# 306 IMT.GBGBX.csv
# 307 IND.IDXUSD.csv
# 308 INGA.NLEUR.csv
# 309 INTC.USUSD.csv
# 310 INTU.USUSD.csv
# 311 INVEB.SESEK.csv
# 312 IPG.USUSD.csv
# 313 ISAT.GBGBX.csv
# 314 ISRG.USUSD.csv
# 315 ITRK.GBGBX.csv
# 316 ITUB.USUSD.csv
# 317 ITV.GBGBX.csv
# 318 ITW.USUSD.csv
# 319 ITX.ESEUR.csv
# 320 IVE.USUSD.csv
# 321 IVW.USUSD.csv
# 322 IWD.USUSD.csv
# 323 IWF.USUSD.csv
# 324 IWM.USUSD.csv
# 325 IYR.USUSD.csv
# 326 JCI.USUSD.csv
# 327 JNJ.USUSD.csv
# 328 JNK.USUSD.csv
# 329 JPM.USUSD.csv
# 330 JPN.IDXJPY.csv
# 331 JWN.USUSD.csv
# 332 K.USUSD.csv
# 333 KBC.BEEUR.csv
# 334 KER.FREUR.csv
# 335 KEY.USUSD.csv
# 336 KGF.GBGBX.csv
# 337 KHC.USUSD.csv
# 338 KMB.USUSD.csv
# 339 KMI.USUSD.csv
# 340 KNIN.CHCHF.csv
# 341 KO.USUSD.csv
# 342 KPN.NLEUR.csv
# 343 KR.USUSD.csv
# 344 KSS.USUSD.csv
# 345 L.USUSD.csv
# 346 LAND.GBGBX.csv
# 347 LEN.USUSD.csv
# 348 LGEN.GBGBX.csv
# 349 LHA.DEEUR.csv
# 350 LHN.CHCHF.csv
# 351 LI.FREUR.csv
# 352 LIGHT.CMDUSD.csv
# 353 LIN.DEEUR.csv
# 354 LLOY.GBGBX.csv
# 355 LLY.USUSD.csv
# 356 LMT.USUSD.csv
# 357 LONN.CHCHF.csv
# 358 LOW.USUSD.csv
# 359 LR.FREUR.csv
# 360 LRCX.USUSD.csv
# 361 LSE.GBGBX.csv
# 362 LTCUSD.csv
# 363 LUV.USUSD.csv
# 364 LVS.USUSD.csv
# 365 LXS.DEEUR.csv
# 366 M.USUSD.csv
# 367 MA.USUSD.csv
# 368 MAERSKB.DKDKK.csv
# 369 MAR.USUSD.csv
# 370 MAT.USUSD.csv
# 371 MC.FREUR.csv
# 372 MCD.USUSD.csv
# 373 MCHP.USUSD.csv
# 374 MCK.USUSD.csv
# 375 MDLZ.USUSD.csv
# 376 MET.USUSD.csv
# 377 MGM.USUSD.csv
# 378 MHG.NONOK.csv
# 379 MKS.GBGBX.csv
# 380 MMM.USUSD.csv
# 381 MNDI.GBGBX.csv
# 382 MO.USUSD.csv
# 383 MPC.USUSD.csv
# 384 MRK.DEEUR.csv
# 385 MRK.USUSD.csv
# 386 MRO.USUSD.csv
# 387 MRW.GBGBX.csv
# 388 MS.USUSD.csv
# 389 MSFT.USUSD.csv
# 390 MT.NLEUR.csv
# 391 MU.USUSD.csv
# 392 MUV2.DEEUR.csv
# 393 NBL.USUSD.csv
# 394 NDA.SESEK.csv
# 395 NEE.USUSD.csv
# 396 NEM.USUSD.csv
# 397 NES1V.FIEUR.csv
# 398 NESN.CHCHF.csv
# 399 NFLX.USUSD.csv
# 400 NG.GBGBX.csv
# 401 NHY.NONOK.csv
# 402 NKE.USUSD.csv
# 403 NLD.IDXEUR.csv
# 404 NOC.USUSD.csv
# 405 NOVN.CHCHF.csv
# 406 NOVOB.DKDKK.csv
# 407 NRE1V.FIEUR.csv
# 408 NRG.USUSD.csv
# 409 NSC.USUSD.csv
# 410 NVDA.USUSD.csv
# 411 NWL.USUSD.csv
# 412 NXT.GBGBX.csv
# 413 NZDCAD.csv
# 414 NZDCHF.csv
# 415 NZDJPY.csv
# 416 NZDUSD.csv
# 417 NZYMB.DKDKK.csv
# 418 OJUICE.CMDUSX.csv
# 419 OKE.USUSD.csv
# 420 OMC.USUSD.csv
# 421 OR.FREUR.csv
# 422 ORA.FREUR.csv
# 423 ORCL.USUSD.csv
# 424 ORK.NONOK.csv
# 425 ORLY.USUSD.csv
# 426 OTE1V.FIEUR.csv
# 427 OUT1V.FIEUR.csv
# 428 OXY.USUSD.csv
# 429 PAH3.DEEUR.csv
# 430 PAYX.USUSD.csv
# 431 PBR.USUSD.csv
# 432 PCAR.USUSD.csv
# 433 PCG.USUSD.csv
# 434 PCLN.USUSD.csv
# 435 PEP.USUSD.csv
# 436 PFC.GBGBX.csv
# 437 PFE.USUSD.csv
# 438 PG.USUSD.csv
# 439 PGR.USUSD.csv
# 440 PH.USUSD.csv
# 441 PHIA.NLEUR.csv
# 442 PLN.IDXPLN.csv
# 443 PM.USUSD.csv
# 444 PNC.USUSD.csv
# 445 PNDORA.DKDKK.csv
# 446 PPG.USUSD.csv
# 447 PRU.GBGBX.csv
# 448 PRU.USUSD.csv
# 449 PSA.USUSD.csv
# 450 PSM.DEEUR.csv
# 451 PSN.GBGBX.csv
# 452 PSON.GBGBX.csv
# 453 PSX.USUSD.csv
# 454 PUB.FREUR.csv
# 455 PXD.USUSD.csv
# 456 PYPL.USUSD.csv
# 457 QCOM.USUSD.csv
# 458 QQQ.USUSD.csv
# 459 RAND.NLEUR.csv
# 460 RB.GBGBX.csv
# 461 RBI.ATEUR.csv
# 462 RBS.GBGBX.csv
# 463 RDSA.NLEUR.csv
# 464 RDSB.GBGBX.csv
# 465 REE.ESEUR.csv
# 466 REGN.USUSD.csv
# 467 REL.GBGBX.csv
# 468 REN.NLEUR.csv
# 469 REP.ESEUR.csv
# 470 RF.USUSD.csv
# 471 RI.FREUR.csv
# 472 RIO.GBGBX.csv
# 473 RMG.GBGBX.csv
# 474 RNO.FREUR.csv
# 475 ROG.CHCHF.csv
# 476 ROST.USUSD.csv
# 477 RR.GBGBX.csv
# 478 RRC.USUSD.csv
# 479 RRS.GBGBX.csv
# 480 RSA.GBGBX.csv
# 481 RTN.USUSD.csv
# 482 RWE.DEEUR.csv
# 483 SAF.FREUR.csv
# 484 SAN.ESEUR.csv
# 485 SAN.FREUR.csv
# 486 SAND.SESEK.csv
# 487 SAP.DEEUR.csv
# 488 SBRY.GBGBX.csv
# 489 SBUX.USUSD.csv
# 490 SCAB.SESEK.csv
# 491 SCHW.USUSD.csv
# 492 SCMN.CHCHF.csv
# 493 SDF.DEEUR.csv
# 494 SEBA.SESEK.csv
# 495 SECUB.SESEK.csv
# 496 SGD.IDXSGD.csv
# 497 SGDJPY.csv
# 498 SGE.GBGBX.csv
# 499 SGO.FREUR.csv
# 500 SGSN.CHCHF.csv
# 501 SHP.GBGBX.csv
# 502 SHW.USUSD.csv
# 503 SIE.DEEUR.csv
# 504 SJM.USUSD.csv
# 505 SKAB.SESEK.csv
# 506 SKFB.SESEK.csv
# 507 SKY.GBGBX.csv
# 508 SLHN.CHCHF.csv
# 509 SLV.USUSD.csv
# 510 SMIN.GBGBX.csv
# 511 SN.GBGBX.csv
# 512 SNAP.USUSD.csv
# 513 SO.USUSD.csv
# 514 SOLB.BEEUR.csv
# 515 SOON.CHCHF.csv
# 516 SOYBEAN.CMDUSX.csv
# 517 SPG.USUSD.csv
# 518 SPY.USUSD.csv
# 519 SREN.CHCHF.csv
# 520 SSE.GBGBX.csv
# 521 STAN.GBGBX.csv
# 522 STERV.FIEUR.csv
# 523 STI.USUSD.csv
# 524 STL.NONOK.csv
# 525 STT.USUSD.csv
# 526 STZ.USUSD.csv
# 527 SU.FREUR.csv
# 528 SUGAR.CMDUSD.csv
# 529 SVT.GBGBX.csv
# 530 SWEDA.SESEK.csv
# 531 SWK.USUSD.csv
# 532 SWMA.SESEK.csv
# 533 SYK.USUSD.csv
# 534 SYMC.USUSD.csv
# 535 SYY.USUSD.csv
# 536 T.USUSD.csv
# 537 TAP.USUSD.csv
# 538 TATE.GBGBX.csv
# 539 TEF.ESEUR.csv
# 540 TEL.NONOK.csv
# 541 TEL2B.SESEK.csv
# 542 TEVA.USUSD.csv
# 543 TGT.USUSD.csv
# 544 TIF.USUSD.csv
# 545 TJX.USUSD.csv
# 546 TKA.DEEUR.csv
# 547 TLS1V.FIEUR.csv
# 548 TLSN.SESEK.csv
# 549 TLT.USUSD.csv
# 550 TLW.GBGBX.csv
# 551 TMO.USUSD.csv
# 552 TPK.GBGBX.csv
# 553 TROW.USUSD.csv
# 554 TRV.USUSD.csv
# 555 TRYJPY.csv
# 556 TSCO.GBGBX.csv
# 557 TSLA.USUSD.csv
# 558 TSM.USUSD.csv
# 559 TSN.USUSD.csv
# 560 TUI1.DEEUR.csv
# 561 TWTR.USUSD.csv
# 562 TXN.USUSD.csv
# 563 UBSG.CHCHF.csv
# 564 UCB.BEEUR.csv
# 565 UG.FREUR.csv
# 566 UHR.CHCHF.csv
# 567 UKGILT.TRGBP.csv
# 568 ULTA.USUSD.csv
# 569 ULVR.GBGBX.csv
# 570 UMI.BEEUR.csv
# 571 UNA.NLEUR.csv
# 572 UNH.USUSD.csv
# 573 UNP.USUSD.csv
# 574 UPS.USUSD.csv
# 575 USA30.IDXUSD.csv
# 576 USA500.IDXUSD.csv
# 577 USATECH.IDXUSD.csv
# 578 USB.USUSD.csv
# 579 USDCAD.csv
# 580 USDCHF.csv
# 581 USDCNH.csv
# 582 USDCZK.csv
# 583 USDDKK.csv
# 584 USDHKD.csv
# 585 USDHUF.csv
# 586 USDILS.csv
# 587 USDJPY.csv
# 588 USDMXN.csv
# 589 USDNOK.csv
# 590 USDPLN.csv
# 591 USDRON.csv
# 592 USDRUB.csv
# 593 USDSEK.csv
# 594 USDSGD.csv
# 595 USDTHB.csv
# 596 USDTRY.csv
# 597 USDZAR.csv
# 598 USO.USUSD.csv
# 599 USSC2000.IDXUSD.csv
# 600 USTBOND.TRUSD.csv
# 601 UTX.USUSD.csv
# 602 UU.GBGBX.csv
# 603 V.USUSD.csv
# 604 VALE.USUSD.csv
# 605 VEA.USUSD.csv
# 606 VFC.USUSD.csv
# 607 VGK.USUSD.csv
# 608 VIAB.USUSD.csv
# 609 VIE.FREUR.csv
# 610 VIV.FREUR.csv
# 611 VK.FREUR.csv
# 612 VLO.USUSD.csv
# 613 VMC.USUSD.csv
# 614 VNA.DEEUR.csv
# 615 VNQ.USUSD.csv
# 616 VOD.GBGBX.csv
# 617 VOE.ATEUR.csv
# 618 VOLVB.SESEK.csv
# 619 VOW3.DEEUR.csv
# 620 VPK.NLEUR.csv
# 621 VRTX.USUSD.csv
# 622 VWS.DKDKK.csv
# 623 VXX.USUSD.csv
# 624 VZ.USUSD.csv
# 625 WBA.USUSD.csv
# 626 WDC.USUSD.csv
# 627 WEIR.GBGBX.csv
# 628 WFC.USUSD.csv
# 629 WHR.USUSD.csv
# 630 WKL.NLEUR.csv
# 631 WMT.USUSD.csv
# 632 WOS.GBGBX.csv
# 633 WPP.GBGBX.csv
# 634 WTB.GBGBX.csv
# 635 WYNN.USUSD.csv
# 636 X.USUSD.csv
# 637 XAGUSD.csv
# 638 XAUUSD.csv
# 639 XLE.USUSD.csv
# 640 XLF.USUSD.csv
# 641 XLI.USUSD.csv
# 642 XLK.USUSD.csv
# 643 XLNX.USUSD.csv
# 644 XLP.USUSD.csv
# 645 XLU.USUSD.csv
# 646 XLV.USUSD.csv
# 647 XLY.USUSD.csv
# 648 XOM.USUSD.csv
# 649 XOP.USUSD.csv
# 650 YUM.USUSD.csv
# 651 ZARJPY.csv
# 652 ZBH.USUSD.csv
# 653 ZURN.CHCHF.csv
# 654 _CON.DEEUR.csv

# %%
skipped = [(os.path.basename(file), error) for file, error in skipped]

# %%
import csv
with open(save_dir,'w') as out:
    csv_out=csv.writer(out)
    csv_out.writerows(skipped)
