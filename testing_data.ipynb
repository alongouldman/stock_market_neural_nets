# %%
import pandas as pd

# %%
df = pd.read_csv('data/dataset.csv', index_col=0, header=[0, 1]).sort_index(axis=1)

# %%
df
# Out:
#                           A                                       AAL          \
#                       close    high      low     open   volume  close    high
# timestamp
# 2017-09-11 09:30:00     NaN     NaN      NaN      NaN      NaN  44.01  44.050
# 2017-09-11 09:31:00  65.460  65.500  65.4100  65.5000  29852.0  44.25  44.250
# 2017-09-11 09:32:00  65.660  65.660  65.4604  65.4604   3435.0  44.27  44.320
# 2017-09-11 09:33:00  65.690  65.700  65.6200  65.6700    700.0  44.34  44.460
# 2017-09-11 09:34:00  65.880  65.880  65.6800  65.6900   2814.0  44.24  44.360
# ...                     ...     ...      ...      ...      ...    ...     ...
# 2018-02-16 15:55:00  72.125  72.130  72.0900  72.0950  17309.0  51.76  51.760
# 2018-02-16 15:56:00  72.070  72.125  72.0700  72.1250  15441.0  51.77  51.780
# 2018-02-16 15:57:00  72.060  72.100  72.0500  72.0700  18096.0  51.75  51.780
# 2018-02-16 15:58:00  72.010  72.060  72.0100  72.0600  22146.0  51.70  51.755
# ...

# %%
symbols = set(df.T.index.get_level_values(0))
print(symbols)
# Out:
# {'HON', 'LRCX', 'ZTS', 'CMS', 'BA', 'DLTR', 'GIS', 'FAST', 'D', 'PEP', 'MAT', 'ED', 'MMC', 'MKC', 'ALB', 'IDXX', 'ROP', 'LEN', 'AFL', 'PSA', 'VZ', 'DAL', 'TSS', 'SYY', 'GD', 'MYL', 'CMI', 'TROW', 'NTAP', 'HSIC', 'BBT', 'PCG', 'ORLY', 'ANTM', 'CRM', 'KSS', 'MCD', 'INTU', 'VIAB', 'COP', 'HRB', 'IP', 'SJM', 'DTE', 'MLM', 'GWW', 'PAYX', 'AEP', 'MA', 'VRSN', 'ETFC', 'ROK', 'INCY', 'GILD', 'WLTW', 'HP', 'HCN', 'HOLX', 'IPG', 'BAC', 'ABC', 'ALLE', 'LEG', 'CMA', 'ULTA', 'VFC', 'DXC', 'DISCK', 'UNH', 'AMT', 'EMN', 'FTV', 'TWX', 'MCO', 'RSG', 'FDX', 'CI', 'BBY', 'QCOM', 'LLL', 'EVHC', 'PVH', 'WMT', 'JEC', 'MAA', 'DVN', 'ADP', 'STZ', 'ETN', 'TJX', 'MGM', 'PRU', 'PNR', 'ANSS', 'HBAN', 'WYNN', 'BDX', 'PCLN', 'SNI', 'USB', 'DE', 'GOOGL', 'CVX', 'SEE', 'UPS', 'UAA', 'HOG', 'NBL', 'AWK', 'PKG', 'NUE', 'NWSA', 'DWDP', 'BXP', 'ARE', 'AOS', 'XEL', 'ES', 'ORCL', 'FFIV', 'JBHT', 'MAS', 'NAVI', 'WYN', 'HPQ', 'AES', 'CA', 'BIIB', 'AAP', 'SYK', 'ADBE', 'EMR', 'STI', 'NLSN', 'XRAY', 'EQT', 'FBHS', 'UNM', 'GO
# ...
